# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"]="3"


import torch
import pickle
import models
torch.cuda.is_available()
# Out:
# True

# %%
fold_regressor_dict = {
    'worst':{
        0: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 2,
            'final_layers': 4,
            'eta_min': 0.001,
            'init_lr': 0.0001,
            'g_pos': 'front',
            'concat_label_mlp': False,
            'weight_decay': 0.0001
        },
        1: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 4,
            'final_layers': 4,
            'eta_min': 0.001,
            'init_lr': 0.0001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.001
        },
        2: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 2,
            'final_layers': 4,
            'eta_min': 0.001,
            'init_lr': 0.0001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.0001
        },            
        3: {
            't_scheduling': 'uniform',
            'g_mlp_layers': 4,
            'final_layers': 4,
            'eta_min': 0.01,
            'init_lr': 0.001,
            'g_pos': 'front',
            'concat_label_mlp': False,
            'weight_decay': 0.0001
        },
        4: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 4,
            'final_layers': 4,
            'eta_min': 0.01,
            'init_lr': 0.00001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.001
        }},
    'erm':{
        0: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 2,
            'final_layers': 12,
            'eta_min': 0.01,
            'init_lr': 0.00001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.001
        },
        1: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 4,
            'final_layers': 4,
            'eta_min': 0.001,
            'init_lr': 0.0001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.001
        },
        2: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 2,
            'final_layers': 4,
            'eta_min': 0.001,
            'init_lr': 0.001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.0001
        },            
        3: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 2,
            'final_layers': 12,
            'eta_min': 0.001,
            'init_lr': 0.00001,
            'g_pos': 'rear',
            'concat_label_mlp': False,
            'weight_decay': 0.0001
        },
        4: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 2,
            'final_layers': 4,
            'eta_min': 0.01,
            'init_lr': 0.0001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.001
        }},
    'gal':{
        0: {
            't_scheduling': 'uniform',
            'g_mlp_layers': 2,
            'final_layers': 4,
            'eta_min': 0.01,
            'init_lr': 0.001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.0001
        },
        1: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 4,
            'final_layers': 4,
            'eta_min': 0.001,
            'init_lr': 0.0001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.001
        },
        2: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 2,
            'final_layers': 4,
            'eta_min': 0.001,
            'init_lr': 0.001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.0001
        },            
        3: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 2,
            'final_layers': 12,
            'eta_min': 0.001,
            'init_lr': 0.0001,
            'g_pos': 'rear',
            'concat_label_mlp': False,
            'weight_decay': 0.001
        },
        4: {
            't_scheduling': 'train-step',
            'g_mlp_layers': 4,
            'final_layers': 4,
            'eta_min': 0.01,
            'init_lr': 0.00001,
            'g_pos': 'rear',
            'concat_label_mlp': True,
            'weight_decay': 0.001
        }}
}

# %%
def assign_group_label(sbp, dbp):
    sbp_label = (sbp - 80) // 10
    dbp_label = (dbp - 40) // 10

    return (sbp_label, dbp_label)
